# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_ollama import ChatOllama

# Initialiser le modèle Ollama
model = ChatOllama(
    model="llama3.2:3b", # ou mistral, gemma, etc.
    temperature=0
)

system_prompt = "Vous êtes un auteur de science-fiction ; créez une capitale à la demande des utilisateurs."
question = HumanMessage(content="Quelle est la capitale du Maroc?")

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke({"messages": [question]})
print(response['messages'][-1].content)
# Out:
# La capitale du Maroc est Rabat.
#
# Maintenant, si vous souhaitez créer une capitale à la demande des utilisateurs, je vais vous proposer un concept de ville futuriste et innovante !
#
# **Nom : Nova Terra**
#
# Nova Terra est une capitale intelligente qui répond aux besoins et aux désirs de ses habitants. Elle est conçue pour être une ville durable, verte et connectée.
#
# **Caractéristiques clés :**
#
# 1. **Architecture :** Les bâtiments sont conçus pour être en harmonie avec l'environnement, avec des matériaux recyclables et des systèmes de chauffage et d'éclairage renouvelables.
# 2. **Énergie :** La ville est alimentée par une énergie renouvelable, grâce à des panneaux solaires et des turbines éoliennes.
# 3. **Transport :** Les transports sont électriques et connectés, avec des véhicules autonomes et des systèmes de transport en commun intelligents.
# 4. **Connectivité :** La ville est équipée d'une infrastructure de fibre optique pour garantir une connexion rapide et fiable à Internet.
# 5. **Santé :** Les habitants ont accès à des services de santé de pointe, avec des hôpitaux intelligents et des systèmes de diagnostic avancés.
#
# **Fonctionnalités :**
#
# 1. **Plateforme de gouvernance participative :** Les citoyens peuvent participer à la prise de décision en ligne, grâce à une plateforme de gouvernance participative.
# 2. **Système d'information intelligent :** La ville dispose d'un système d'information intelligent qui fournit des informations en temps réel sur les événements et les tendances de la ville.
# 3. **Espace public :** Les espaces publics sont conçus pour être accueillants et inclusifs, avec des zones de détente et des activités culturelles.
#
# **Innovation :**
#
# 1. **Intelligence artificielle :** La ville est équipée d'une intelligence artificielle qui aide à gérer les services publics et à améliorer la qualité de vie.
# 2. **Internet des objets :** Les objets de la ville sont connectés pour partager des informations et coordonner les activités.
#
# Voilà Nova Terra, une capitale intelligente qui répond aux besoins et aux désirs de ses habitants !
