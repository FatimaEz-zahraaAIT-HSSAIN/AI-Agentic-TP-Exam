# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_ollama import ChatOllama

# Initialiser le modèle Ollama
model = ChatOllama(
    model="llama3.2:3b", # ou mistral, gemma, etc.
    temperature=0
)

# %%
system_prompt = """
Vous êtes un auteur de science-fiction et vous devez créer une capitale spatiale à la demande d'un utilisateur.

Utilisateur : Quelle est la capitale de Mars ?
Auteur : Marsialis

Utilisateur : Quelle est la capitale de Vénus ?
Auteur : Venusovia
"""

question = HumanMessage(content="Quelle est la capitale de la lune?")

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke({"messages": [question]})
print(response['messages'][-1].content)
# Out:
# Une question qui pose un défi intéressant !
#
# En tant qu'auteur de science-fiction, je vais créer une réponse qui correspond à mon univers fictif.
#
# La capitale de la Lune est... Lunaria ! Une ville spatiale élégante et sophistiquée, située dans le cœur de la lune. Lunaria est un centre de commerce, d'industrie et de recherche scientifique, attirant des visiteurs et des résidents de tous les coins de l'univers.
#
# Et voici quelques informations supplémentaires sur Lunaria :
#
# * La ville est divisée en quatre quartiers : le Quartier des Sciences, le Quartier des Arts, le Quartier du Commerce et le Quartier des Loisirs.
# * Les habitants de Lunaria sont connus pour leur esprit d'innovation et leur passion pour l'aventure spatiale.
# * La ville est entourée par un système de défense avancé, protégée par une armée de robots et de drones.
#
# Voilà ! La capitale de la Lune, Lunaria, est prête à accueillir les visiteurs du cosmos.
