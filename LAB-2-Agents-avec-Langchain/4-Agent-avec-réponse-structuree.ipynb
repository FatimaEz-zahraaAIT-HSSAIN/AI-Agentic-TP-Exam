# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_ollama import ChatOllama

# Initialiser le modèle Ollama
model = ChatOllama(
    model="llama3.2:3b", # ou mistral, gemma, etc.
    temperature=0
)

system_prompt = """
Vous êtes un auteur de science-fiction et vous devez créer une capitale spatiale à la demande d'un utilisateur.

Veuillez respecter la structure ci-dessous.
Nom : Nom de la capitale
Localisation : Lieu où elle est située
Ambiance : Description en 2 ou 3 mots
Économie : Principaux secteurs d'activité
"""
question = HumanMessage(content="Quelle est la capitale de la lune?")
scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke({"messages": [question]})
print(response['messages'][-1].content)
# Out:
# Je crée une capitale spatiale à la demande !
#
# **Nom :** Lunaria
# **Localisation :** Surface de la lune, dans le bassin du lac Serenity
# **Ambiance :** Futuriste Éclatante
#
# **Économie :**
#
# * **Tourisme Spatiale** : Attracter des touristes qui visitent la capitale pour découvrir son environnement unique et ses attractions spatiales.
# * **Industrie de l'Energie** : Exploiter les ressources énergétiques renouvelables disponibles sur la lune, telles que le soleil et les panneaux solaires.
# * **Recherche Scientifique** : Abriter des laboratoires et des instituts de recherche qui étudient les phénomènes spatiaux et développent de nouvelles technologies pour l'exploration du système solaire.
#
# Lunaria est une ville futuriste et éclatante, où la technologie et la science sont mises à l'honneur. Les habitants de Lunaria sont des scientifiques, des ingénieurs et des entrepreneurs qui travaillent ensemble pour créer un avenir meilleur pour l'humanité.
